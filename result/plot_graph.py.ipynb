# %%
import matplotlib.pyplot as plt
import numpy as np


dense_graph_0_1 = np.loadtxt('density_7_sparse_graph.txt').reshape(20, 4)

print(dense_graph_0_1)


plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,1])

plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,2])

plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,3])

plt.title("Le temp d'execution pour le graphe dense de densite 0.1")
plt.xlabel("log10(nb vertex du graphe)")
plt.ylabel("temp d'execution")
plt.legend(["Dijkstra naif avec Matrice d'adjacente", "Dijkstra min heap avec Matrice d'adjacente", "Dijkstra min heap avec Liste d'adjacente"])
plt.savefig("Dijkstra resultat avec sparse graphe de densite3.png", transparent = False)
# Out:
# [[1.000000e+03 9.851000e-03 3.278000e-03 1.041000e-03]
#  [2.000000e+03 4.179000e-02 1.098700e-02 2.079000e-03]
#  [3.000000e+03 8.820400e-02 2.574700e-02 4.293000e-03]
#  [4.000000e+03 1.583110e-01 4.523100e-02 6.379000e-03]
#  [5.000000e+03 2.494340e-01 6.896600e-02 1.265500e-02]
#  [6.000000e+03 3.602750e-01 9.471200e-02 1.266700e-02]
#  [7.000000e+03 4.943390e-01 1.252690e-01 1.303700e-02]
#  [8.000000e+03 6.482380e-01 1.570670e-01 1.683900e-02]
#  [9.000000e+03 8.219880e-01 1.969150e-01 2.053300e-02]
#  [1.000000e+04 1.019621e+00 2.375860e-01 2.402100e-02]
#  [1.100000e+04 1.231577e+00 2.859420e-01 2.836400e-02]
#  [1.200000e+04 1.469707e+00 3.376460e-01 3.153100e-02]
#  [1.300000e+04 1.726309e+00 3.930810e-01 3.722500e-02]
#  [1.400000e+04 2.006411e+00 4.523270e-01 4.304600e-02]
#  [1.500000e+04 2.296612e+00 5.177920e-01 5.050500e-02]
#  [1.600000e+04 2.618788e+00 5.884220e-01 6.040900e-02]
#  [1.700000e+04 2.960970e+00 6.647650e-01 6.685700e-02]
#  [1.800000e+04 3.321401e+00 7.384830e-01 7.763800e-02]
#  [1.900000e+04 3.695886e+00 8.201790e-01 8.637200e-02]
#  [2.000000e+04 4.102814e+00 9.080890e-01 9.709200e-02]]
