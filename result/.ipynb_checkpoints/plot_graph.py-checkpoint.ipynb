# %%
import matplotlib.pyplot as plt
import numpy as np


dense_graph_0_1 = np.loadtxt('density_3_sparse_graph.txt').reshape(20, 4)

print(dense_graph_0_1)


plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,1])

plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,2])

plt.plot(np.log10(dense_graph_0_1[:,0]), dense_graph_0_1[:,3])

plt.title("Le temp d'execution pour le graphe dense de densite 0.1")
plt.xlabel("log10(nb vertex du graphe)")
plt.ylabel("temp d'execution")
plt.legend(["Dijkstra naif avec Matrice d'adjacente", "Dijkstra min heap avec Matrice d'adjacente", "Dijkstra min heap avec Liste d'adjacente"])
plt.savefig("Dijkstra resultat avec dense graphe de densite2.png", transparent = False)
# Out:
# [[1.0000e+03 1.7000e-02 1.1000e-02 2.9000e-02]
#  [2.0000e+03 6.9000e-02 4.2000e-02 9.5000e-02]
#  [3.0000e+03 1.5400e-01 9.1000e-02 2.1800e-01]
#  [4.0000e+03 2.9200e-01 1.6400e-01 4.0300e-01]
#  [5.0000e+03 4.3200e-01 2.4000e-01 6.4500e-01]
#  [6.0000e+03 6.2900e-01 3.4000e-01 9.2600e-01]
#  [7.0000e+03 8.4800e-01 4.6300e-01 1.3160e+00]
#  [8.0000e+03 1.1110e+00 6.0100e-01 1.8940e+00]
#  [9.0000e+03 1.5200e+00 7.5400e-01 2.5100e+00]
#  [1.0000e+04 1.8540e+00 9.9200e-01 4.5550e+00]
#  [1.1000e+04 2.2250e+00 1.1770e+00 4.1460e+00]
#  [1.2000e+04 2.5300e+00 1.3430e+00 5.1750e+00]
#  [1.3000e+04 2.9550e+00 1.5660e+00 6.1560e+00]
#  [1.4000e+04 3.4380e+00 1.8200e+00 7.2840e+00]
#  [1.5000e+04 3.9390e+00 2.0790e+00 8.4450e+00]
#  [1.6000e+04 4.4860e+00 2.3640e+00 9.8580e+00]
#  [1.7000e+04 5.0560e+00 2.6720e+00 2.0288e+01]
#  [1.8000e+04 5.6540e+00 2.9760e+00 3.9543e+01]
#  [1.9000e+04 6.8300e+00 3.3140e+00 4.0139e+01]
#  [2.0000e+04 7.3830e+00 3.8800e+00 6.8768e+01]]
